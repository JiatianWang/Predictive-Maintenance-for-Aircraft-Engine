# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv('train_df.csv')

# %%
train_df.head()
train_df.shape
# Out:
# (20631, 20)

# %%
Cols = ['Unit','Cycle','Setting1','Setting2','Setting3',
           'Fan °R1', 'LPC °R2', 'HPC °R3','LPT °R4',
           'Fan Psia5', 'Bypass-duct psia6','HPC psia7',
           'Fan rpm8','Core rpm9', 'Engin P ratio10', 'Hpc psia11',
           'Ratio of fuel12','Corrected fan rpm13', 'Corrected core rpm14',
           'Bypass ratio15', 'Burner fuel-air ratio16','BE17','Demanded fan speed18',
           'Demanded corrected fan speed19','HPT coolant bleed lbm/s20','LPT coolant bleed lbm/s21','s22','s23']

# %%
test_df = pd.read_csv('PM_test.txt',sep = ' ',header = None)

# %%
test_df.columns = Cols
test_df.head()
test_df.shape
# Out:
# (13096, 28)

# %%
# Load truth rul data
df_truth = pd.read_csv('PM_truth.txt', header = None)
df_truth = df_truth.reset_index()
df_truth.columns = ['Unit','True max cycle']
df_truth['Unit'] = df_truth['Unit'].apply(lambda x: x+1)
df_truth
# Out:
#     Unit  True max cycle
# 0      1             112
# 1      2              98
# 2      3              69
# 3      4              82
# 4      5              91
# ..   ...             ...
# 95    96             137
# 96    97              82
# 97    98              59
# 98    99             117
# 99   100              20
#
# [100 rows x 2 columns]

# %%
# retrieve the max cycles per engine: RUL
test_rul = pd.DataFrame(test_df.groupby('Unit')['Cycle'].max()).reset_index()

# merge the RULs into the training data
test_rul.columns = ['Unit','Max']
test_rul = test_rul.merge(df_truth, on = 'Unit')
test_rul['RUL'] = test_rul['Max'] + test_rul['True max cycle']

test_df = test_df.merge(test_rul, on =['Unit'], how = 'left')
test_df
# Out:
#        Unit  Cycle  Setting1  Setting2  Setting3  Fan °R1  LPC °R2  HPC °R3  \
# 0         1      1    0.0023    0.0003     100.0   518.67   643.02  1585.29
# 1         1      2   -0.0027   -0.0003     100.0   518.67   641.71  1588.45
# 2         1      3    0.0003    0.0001     100.0   518.67   642.46  1586.94
# 3         1      4    0.0042    0.0000     100.0   518.67   642.44  1584.12
# 4         1      5    0.0014    0.0000     100.0   518.67   642.51  1587.19
# ...     ...    ...       ...       ...       ...      ...      ...      ...
# 13091   100    194    0.0049    0.0000     100.0   518.67   643.24  1599.45
# 13092   100    195   -0.0011   -0.0001     100.0   518.67   643.22  1595.69
# 13093   100    196   -0.0006   -0.0003     100.0   518.67   643.44  1593.15
# 13094   100    197   -0.0038    0.0001     100.0   518.67   643.26  1594.99
# 13095   100    198    0.0013    0.0003     100.0   518.67   642.95  1601.62
#
#        LPT °R4  Fan Psia5  ...  BE17  Demanded fan speed18  \
# 0      1398.21      14.62  ...   392                  2388
# 1      1395.42      14.62  ...   393                  2388
# 2      1401.34      14.62  ...   393                  2388
# 3      1406.42      14.62  ...   391                  2388
# 4      1401.92      14.62  ...   390                  2388
# ...        ...        ...  ...   ...                   ...
# 13091  1415.79      14.62  ...   394                  2388
# 13092  1422.05      14.62  ...   395                  2388
# 13093  1406.82      14.62  ...   395                  2388
# 13094  1419.36      14.62  ...   395                  2388
# 13095  1424.99      14.62  ...   396                  2388
#
#        Demanded corrected fan speed19  HPT coolant bleed lbm/s20  \
# 0                               100.0                      38.86
# 1                               100.0                      39.02
# 2                               100.0                      39.08
# 3                               100.0                      39.00
# 4                               100.0                      38.99
# ...                               ...                        ...
# 13091                           100.0                      38.65
# 13092                           100.0                      38.57
# 13093                           100.0                      38.62
# 13094                           100.0                      38.66
# 13095                           100.0                      38.70
#
#        LPT coolant bleed lbm/s21  s22  s23  Max  True max cycle  RUL
# 0                        23.3735  NaN  NaN   31             112  143
# 1                        23.3916  NaN  NaN   31             112  143
# 2                        23.4166  NaN  NaN   31             112  143
# 3                        23.3737  NaN  NaN   31             112  143
# 4                        23.4130  NaN  NaN   31             112  143
# ...                          ...  ...  ...  ...             ...  ...
# 13091                    23.1974  NaN  NaN  198              20  218
# 13092                    23.2771  NaN  NaN  198              20  218
# 13093                    23.2051  NaN  NaN  198              20  218
# 13094                    23.2699  NaN  NaN  198              20  218
# 13095                    23.1855  NaN  NaN  198              20  218
#
# [13096 rows x 31 columns]

# %%
test_df['RUL'] = test_df['RUL'] - test_df['Cycle']
test_df.drop(['Max','True max cycle'], axis = 1, inplace = True)
test_df
# Out:
#        Unit  Cycle  Setting1  Setting2  Setting3  Fan °R1  LPC °R2  HPC °R3  \
# 0         1      1    0.0023    0.0003     100.0   518.67   643.02  1585.29
# 1         1      2   -0.0027   -0.0003     100.0   518.67   641.71  1588.45
# 2         1      3    0.0003    0.0001     100.0   518.67   642.46  1586.94
# 3         1      4    0.0042    0.0000     100.0   518.67   642.44  1584.12
# 4         1      5    0.0014    0.0000     100.0   518.67   642.51  1587.19
# ...     ...    ...       ...       ...       ...      ...      ...      ...
# 13091   100    194    0.0049    0.0000     100.0   518.67   643.24  1599.45
# 13092   100    195   -0.0011   -0.0001     100.0   518.67   643.22  1595.69
# 13093   100    196   -0.0006   -0.0003     100.0   518.67   643.44  1593.15
# 13094   100    197   -0.0038    0.0001     100.0   518.67   643.26  1594.99
# 13095   100    198    0.0013    0.0003     100.0   518.67   642.95  1601.62
#
#        LPT °R4  Fan Psia5  ...  Bypass ratio15  Burner fuel-air ratio16  BE17  \
# 0      1398.21      14.62  ...          8.4052                     0.03   392
# 1      1395.42      14.62  ...          8.3803                     0.03   393
# 2      1401.34      14.62  ...          8.4441                     0.03   393
# 3      1406.42      14.62  ...          8.3917                     0.03   391
# 4      1401.92      14.62  ...          8.4031                     0.03   390
# ...        ...        ...  ...             ...                      ...   ...
# 13091  1415.79      14.62  ...          8.4715                     0.03   394
# 13092  1422.05      14.62  ...          8.4512                     0.03   395
# 13093  1406.82      14.62  ...          8.4569                     0.03   395
# 13094  1419.36      14.62  ...          8.4711                     0.03   395
# 13095  1424.99      14.62  ...          8.4903                     0.03   396
#
#        Demanded fan speed18  Demanded corrected fan speed19  \
# 0                      2388                           100.0
# 1                      2388                           100.0
# 2                      2388                           100.0
# 3                      2388                           100.0
# 4                      2388                           100.0
# ...                     ...                             ...
# 13091                  2388                           100.0
# 13092                  2388                           100.0
# 13093                  2388                           100.0
# 13094                  2388                           100.0
# 13095                  2388                           100.0
#
#        HPT coolant bleed lbm/s20  LPT coolant bleed lbm/s21  s22  s23  RUL
# 0                          38.86                    23.3735  NaN  NaN  142
# 1                          39.02                    23.3916  NaN  NaN  141
# 2                          39.08                    23.4166  NaN  NaN  140
# 3                          39.00                    23.3737  NaN  NaN  139
# 4                          38.99                    23.4130  NaN  NaN  138
# ...                          ...                        ...  ...  ...  ...
# 13091                      38.65                    23.1974  NaN  NaN   24
# 13092                      38.57                    23.2771  NaN  NaN   23
# 13093                      38.62                    23.2051  NaN  NaN   22
# 13094                      38.66                    23.2699  NaN  NaN   21
# 13095                      38.70                    23.1855  NaN  NaN   20
#
# [13096 rows x 29 columns]

# %%
# # add on True rul
# test_df = test_df.merge(df_truth, on = ['Unit'], how = 'left', suffixes=('', '_y'))
# test_df['True RUL'] = test_df['True max cycle'] - test_df['Cycle']
# test_df.drop(['True max cycle'], axis = 1, inplace = True)
# test_df

# %%
col_to_drop = ['Setting3','Fan °R1','Fan Psia5','Engin P ratio10','Burner fuel-air ratio16',
               'Demanded fan speed18','Demanded corrected fan speed19','s22','s23']

# %%
# train_df.drop(col_to_drop, axis = 1, inplace = True)

# %%
test_df.drop(col_to_drop, axis = 1, inplace = True)

# %%
test_df
# Out:
#        Unit  Cycle  Setting1  Setting2  LPC °R2  HPC °R3  LPT °R4  \
# 0         1      1    0.0023    0.0003   643.02  1585.29  1398.21
# 1         1      2   -0.0027   -0.0003   641.71  1588.45  1395.42
# 2         1      3    0.0003    0.0001   642.46  1586.94  1401.34
# 3         1      4    0.0042    0.0000   642.44  1584.12  1406.42
# 4         1      5    0.0014    0.0000   642.51  1587.19  1401.92
# ...     ...    ...       ...       ...      ...      ...      ...
# 13091   100    194    0.0049    0.0000   643.24  1599.45  1415.79
# 13092   100    195   -0.0011   -0.0001   643.22  1595.69  1422.05
# 13093   100    196   -0.0006   -0.0003   643.44  1593.15  1406.82
# 13094   100    197   -0.0038    0.0001   643.26  1594.99  1419.36
# 13095   100    198    0.0013    0.0003   642.95  1601.62  1424.99
#
#        Bypass-duct psia6  HPC psia7  Fan rpm8  Core rpm9  Hpc psia11  \
# 0                  21.61     553.90   2388.04    9050.17       47.20
# 1                  21.61     554.85   2388.01    9054.42       47.50
# 2                  21.61     554.11   2388.05    9056.96       47.50
# 3                  21.61     554.07   2388.03    9045.29       47.28
# 4                  21.61     554.16   2388.01    9044.55       47.31
# ...                  ...        ...       ...        ...         ...
# 13091              21.61     553.41   2388.02    9142.37       47.69
# 13092              21.61     553.22   2388.05    9140.68       47.60
# 13093              21.61     553.04   2388.11    9146.81       47.57
# 13094              21.61     553.37   2388.07    9148.85       47.61
# 13095              21.61     552.48   2388.06    9155.03       47.80
#
#        Ratio of fuel12  Corrected fan rpm13  Corrected core rpm14  \
# 0               521.72              2388.03               8125.55
# 1               522.16              2388.06               8139.62
# 2               521.97              2388.03               8130.10
# 3               521.38              2388.05               8132.90
# 4               522.15              2388.03               8129.54
# ...                ...                  ...                   ...
# 13091           520.69              2388.00               8213.28
# 13092           521.05              2388.09               8210.85
# 13093           521.18              2388.04               8217.24
# 13094           521.33              2388.08               8220.48
# 13095           521.07              2388.05               8214.64
#
#        Bypass ratio15  BE17  HPT coolant bleed lbm/s20  \
# 0              8.4052   392                      38.86
# 1              8.3803   393                      39.02
# 2              8.4441   393                      39.08
# 3              8.3917   391                      39.00
# 4              8.4031   390                      38.99
# ...               ...   ...                        ...
# 13091          8.4715   394                      38.65
# 13092          8.4512   395                      38.57
# 13093          8.4569   395                      38.62
# 13094          8.4711   395                      38.66
# 13095          8.4903   396                      38.70
#
#        LPT coolant bleed lbm/s21  RUL
# 0                        23.3735  142
# 1                        23.3916  141
# 2                        23.4166  140
# 3                        23.3737  139
# 4                        23.4130  138
# ...                          ...  ...
# 13091                    23.1974   24
# 13092                    23.2771   23
# 13093                    23.2051   22
# 13094                    23.2699   21
# 13095                    23.1855   20
#
# [13096 rows x 20 columns]

# %%
train_df
# Out:
#        Unit  Cycle  Setting1  Setting2  Setting3  Fan °R1  LPC °R2  HPC °R3  \
# 0         1      1   -0.0007   -0.0004     100.0   518.67   641.82  1589.70
# 1         1      2    0.0019   -0.0003     100.0   518.67   642.15  1591.82
# 2         1      3   -0.0043    0.0003     100.0   518.67   642.35  1587.99
# 3         1      4    0.0007    0.0000     100.0   518.67   642.35  1582.79
# 4         1      5   -0.0019   -0.0002     100.0   518.67   642.37  1582.85
# ...     ...    ...       ...       ...       ...      ...      ...      ...
# 20626   100    196   -0.0004   -0.0003     100.0   518.67   643.49  1597.98
# 20627   100    197   -0.0016   -0.0005     100.0   518.67   643.54  1604.50
# 20628   100    198    0.0004    0.0000     100.0   518.67   643.42  1602.46
# 20629   100    199   -0.0011    0.0003     100.0   518.67   643.23  1605.26
# 20630   100    200   -0.0032   -0.0005     100.0   518.67   643.85  1600.38
#
#        LPT °R4  Fan Psia5  ...  Corrected fan rpm13  Corrected core rpm14  \
# 0      1400.60      14.62  ...              2388.02               8138.62
# 1      1403.14      14.62  ...              2388.07               8131.49
# 2      1404.20      14.62  ...              2388.03               8133.23
# 3      1401.87      14.62  ...              2388.08               8133.83
# 4      1406.22      14.62  ...              2388.04               8133.80
# ...        ...        ...  ...                  ...                   ...
# 20626  1428.63      14.62  ...              2388.26               8137.60
# 20627  1433.58      14.62  ...              2388.22               8136.50
# 20628  1428.18      14.62  ...              2388.24               8141.05
# 20629  1426.53      14.62  ...              2388.23               8139.29
# 20630  1432.14      14.62  ...              2388.26               8137.33
#
#        Bypass ratio15  Burner fuel-air ratio16  BE17  Demanded fan speed18  \
# 0              8.4195                     0.03   392                  2388
# 1              8.4318                     0.03   392                  2388
# 2              8.4178                     0.03   390                  2388
# 3              8.3682                     0.03   392                  2388
# 4              8.4294                     0.03   393                  2388
# ...               ...                      ...   ...                   ...
# 20626          8.4956                     0.03   397                  2388
# 20627          8.5139                     0.03   395                  2388
# 20628          8.5646                     0.03   398                  2388
# 20629          8.5389                     0.03   395                  2388
# 20630          8.5036                     0.03   396                  2388
#
#        Demanded corrected fan speed19  HPT coolant bleed lbm/s20  \
# 0                               100.0                      39.06
# 1                               100.0                      39.00
# 2                               100.0                      38.95
# 3                               100.0                      38.88
# 4                               100.0                      38.90
# ...                               ...                        ...
# 20626                           100.0                      38.49
# 20627                           100.0                      38.30
# 20628                           100.0                      38.44
# 20629                           100.0                      38.29
# 20630                           100.0                      38.37
#
#        LPT coolant bleed lbm/s21  RUL
# 0                        23.4190  191
# 1                        23.4236  190
# 2                        23.3442  189
# 3                        23.3739  188
# 4                        23.4044  187
# ...                          ...  ...
# 20626                    22.9735    4
# 20627                    23.1594    3
# 20628                    22.9333    2
# 20629                    23.0640    1
# 20630                    23.0522    0
#
# [20631 rows x 27 columns]

# %%
col_to_drop_train = ['Setting3','Fan °R1','Fan Psia5','Engin P ratio10','Burner fuel-air ratio16',
               'Demanded fan speed18','Demanded corrected fan speed19']

# %%
train_df.drop(col_to_drop_train, axis = 1, inplace = True)

# %%
train_df.to_csv('train_df.csv',index = None)
test_df.to_csv('test_df.csv',index = None)
